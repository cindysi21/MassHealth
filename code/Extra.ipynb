# %%
#Finds most visited locations
g = emergency[emergency['LowIncome']==1]
g.sort_values(by=['Zipcode'])
h = g.groupby('Zipcode').count()
h.sort_values(by=['ID']).tail(20)
# Out:
#           ID  DATE  PATIENT  CODE  DESCRIPTION  REASONCODE  REASONDESCRIPTION  \
# Zipcode
# 01002     52    52       52    52           52          35                 35
# 01843     64    64       64    64           64          17                 17
# 01852     65    65       65    65           65          16                 16
# 01020     65    65       65    65           65          28                 28
# 02302     70    70       70    70           70          23                 23
# 01082     70    70       70    70           70          19                 19
# 01420     74    74       74    74           74          32                 32
# 02169     75    75       75    75           75          29                 29
# 02723     77    77       77    77           77          36                 36
# 01104     91    91       91    91           91          10                 10
# 02301     92    92       92    92           92          20                 20
# ...

# %% [markdown]
# INFLUENZA IMMUNIZATION STAT

# %%
# Out:
# array(['hispanic', 'asian', 'black', 'white', 'black or african american'],
#       dtype=object)

# %% [markdown]
# patientsCSV

# %%
# Out:
#                                         ID BIRTHDATE DEATHDATE MARITAL  \
# 17    1131717c-e009-446d-b353-0b865cbb4194   1/20/32         0       M
# 22    86fc9c5b-ce25-4f37-850b-697fcd3256c1   8/23/90         0       M
# 31    17ac2a91-9629-4c6f-bbb4-9e462a453216   3/28/90         0       M
# 45    a7c79f2a-026b-478a-ada4-060c584a8b12   8/20/17   12/9/02       M
# 70    10fd692e-fdef-4aa6-b010-8a95005b59f1   1/16/12         0     NaN
# 97    2ff59946-e6d0-492e-8704-a98296eedd4c  11/24/97   5/22/17     NaN
# 104   7a7d1ba4-2e57-4c55-81e6-1f3a37da6645  12/15/05         0     NaN
# 144   18e9f2ff-e9a9-48f4-a129-4a0e5c80c610    2/3/05         0     NaN
# 147   e489813c-d670-4b7c-9ee2-fb13f40caac1   3/14/13         0     NaN
# 195   f9a49fd7-d784-4081-a537-7219edab2bfb   1/12/36    6/1/08       M
# 277   6c713e1c-543e-41c9-ae98-fe753d3c50fe   6/17/31   9/26/07       M
# 315   cda9a70b-87da-4fd1-87f9-9563be88e492   2/11/72         0       S
# ...

# %%
emergency[emergency['YearDeath']==1]
# Out:
#                                          ID       DATE  \
# 53     2d2c4fc1-574c-4fbe-9fbc-bc50779d96f7 2011-04-07
# 54     e18875df-6b04-4bf9-abe1-4fe7d092cd94 2012-03-25
# 106    c3ecf43e-51b9-4783-b303-4cf2a2307fc7 2016-02-05
# 107    f088bebb-a51b-4928-a39d-47746accb827 2016-08-22
# 257    e63a3fa9-9e21-4d20-8c1f-f79403672016 2010-10-14
# ...                                     ...        ...
# 19211  b5cb9d8a-c10f-4759-88f2-1238218d1b53 2014-05-07
# 20343  bd341b34-b178-4a6c-bbc7-564242d11512 2012-11-03
# 20344  9c0cd96f-9048-4fd9-af65-4a8b3748beac 2012-11-21
# 20345  736e13f7-4dc5-4e49-8e0e-2e28115fca12 2013-01-05
# 20346  82172a31-7c9e-43ad-8019-2fc9d16f5ad9 2013-01-25
#
#                                     PATIENT       CODE  \
# 53     31410948-38be-4990-be5e-a47ab44f33a1  185349003
# 54     31410948-38be-4990-be5e-a47ab44f33a1  308646001
# 106    2c884d0f-62a1-4371-becc-36a98cdc4f52  185349003
# 107    2c884d0f-62a1-4371-becc-36a98cdc4f52  308646001
# ...

# %%
f = observationsCSV.groupby('DESCRIPTION').count()
f[f['DATE']>100]
p = observationsCSV[observationsCSV['DESCRIPTION']=='Housing status']
emergency['Homeless'] = emergency['PATIENT'].map(lambda x: 1 if x in p['PATIENT'].unique() else 0)
emergency[emergency['Homeless']==1]
# Out:
#                   ID  DATE  PATIENT  CODE  DESCRIPTION  REASONCODE  \
# HouseholdIncome
# -1.0             110   110      110   110          110          50
#  18843.0          30    30       30    30           30           9
#  22956.0          14    14       14    14           14           5
#  26313.0         104   104      104   104          104          11
#  28351.0          27    27       27    27           27          10
# ...              ...   ...      ...   ...          ...         ...
#  157005.0         46    46       46    46           46          10
#  158250.0          9     9        9     9            9           7
#  164013.0         67    67       67    67           67           5
#  179655.0         55    55       55    55           55          17
#  191744.0         44    44       44    44           44          18
#
#                  REASONDESCRIPTION  DeathDate  Death  DeathDifference  ...  \
# ...

# %%
emergency
# Out:
#                                          ID       DATE  \
# 0      5114a5b4-64b8-47b2-82a6-0ce24aae0943 2008-03-11
# 1      4d451e22-a354-40c9-8b33-b6126158666d 2009-01-11
# 2      bdb926b8-5b6d-4366-bbe9-76fe3f3fbc4f 2009-04-07
# 3      f45c623f-a5e7-47a0-8cce-cfe19d16c47a 2010-06-04
# 4      bed7ecff-b41c-422b-beac-ea00c8b02837 2010-10-16
# ...                                     ...        ...
# 20517  c8fa6e8f-5557-4316-90cc-f27d1d76de7a 2009-01-27
# 20518  be02ee7e-41b5-4d89-b693-97ae97e9a794 2011-04-03
# 20519  e277ecc6-5cbf-4b8f-958c-cdbd171269c3 2012-11-30
# 20520  efac59ce-e64f-4a06-baf4-6be9c7346f26 2013-03-16
# 20521  33518a35-4a91-4347-b78a-f83a060abe42 2015-04-14
#
#                                     PATIENT       CODE  \
# 0      71949668-1c2e-43ae-ab0a-64654608defb  185349003
# 1      71949668-1c2e-43ae-ab0a-64654608defb  185345009
# 2      71949668-1c2e-43ae-ab0a-64654608defb  185349003
# 3      71949668-1c2e-43ae-ab0a-64654608defb  698314001
# ...

# %%
RACE OF ZIPCODES

# %%
lowIncome = zaiMerge[zaiMerge['HouseholdIncome'] < 60000]
lowIncome['Patient'] = lowIncome['ZCTA'].map(lambda x:1 if x in emergency['Zipcode'].unique() else 0)
lowIncomeP = lowIncome[lowIncome['Patient']==1]
lowIncomeP = lowIncomeP[lowIncomeP['YearDeath']==1]
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
lowIncome
# Out:
#       ZCTA  HouseholdIncome  HouseholdMOE         Family         Married  \
# 0    01001            56714          6167  [82512, 8931]   [87939, 8234]
# 1    01002            48923          4421  [94489, 9366]  [109458, 8012]
# 2    01002            48923          4421  [94489, 9366]  [109458, 8012]
# 3    01002            48923          4421  [94489, 9366]  [109458, 8012]
# 4    01003               -1            -1       [-1, -1]        [-1, -1]
# ..     ...              ...           ...            ...             ...
# 661  02740            36105          2158  [48481, 4197]   [66632, 4275]
# 663  02744            32221          3823  [45186, 2887]   [55448, 7930]
# 664  02745            52777          2533  [64288, 5073]   [80062, 3628]
# 665  02746            28351          2753  [28927, 3418]   [46789, 6202]
# 679  02780            51820          2100  [67574, 5749]   [84156, 2654]
#
#          Nonfamily  Patient
# 0    [33768, 7947]        1
# 1    [27251, 5217]        1
# ...

# %%
lowIncomeP
# Out:
#       ZCTA  HouseholdIncome  HouseholdMOE         Family         Married  \
# 0    01001            56714          6167  [82512, 8931]   [87939, 8234]
# 1    01002            48923          4421  [94489, 9366]  [109458, 8012]
# 2    01002            48923          4421  [94489, 9366]  [109458, 8012]
# 3    01002            48923          4421  [94489, 9366]  [109458, 8012]
# 4    01003               -1            -1       [-1, -1]        [-1, -1]
# ..     ...              ...           ...            ...             ...
# 656  02726            69930          5834  [82429, 4907]   [89657, 8455]
# 663  02744            32221          3823  [45186, 2887]   [55448, 7930]
# 664  02745            52777          2533  [64288, 5073]   [80062, 3628]
# 665  02746            28351          2753  [28927, 3418]   [46789, 6202]
# 679  02780            51820          2100  [67574, 5749]   [84156, 2654]
#
#          Nonfamily  Patient
# 0    [33768, 7947]        1
# 1    [27251, 5217]        1
# ...

# %%
lowIncomeP['Hispanic'] =None
lowIncomeP['White'] =None
lowIncomeP['Asian'] =None
lowIncomeP['Black'] =None
lowIncomeP['Death'] = None
for index,row in lowIncomeP.iterrows():
    zipc = emergency[emergency['Zipcode'] == row['ZCTA']]
    lowIncomeP.loc[index,'Hispanic'] = zipc['Hispanic'].sum()
    lowIncomeP.loc[index,'Asian'] = zipc['Asian'].sum()
    lowIncomeP.loc[index,'White'] = zipc['White'].sum()
    lowIncomeP.loc[index,'Black'] = zipc['Black'].sum()
    lowIncomeP.loc[index,'Death'] = zipc['YearDeath'].sum()
lowIncomeP[lowIncomeP['Death']>3]
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [raw]
# emergency

# %%
h['HomeZip'].unique()
# Out:
# array(['02118', '02111', '02215', '02203', '02127', '02109', '02293',
#        '02210', '02283', '02204', '02129', '02136', '02196', '02119',
#        '02130', '02113', '02126', '02298', '02131', '02124', '02163',
#        '02297', '02122', '02284', '02114', '02211', '02206', '02137'],
#       dtype=object)

# %%
h[h['HomeZip']=='02118']
# Out:
#                                        ID BIRTHDATE DEATHDATE MARITAL  \
# 11   16077486-5747-4abe-8321-ba290fb7197c  12/28/53   8/21/98       S
# 43   cc1924a0-f617-447a-8788-a6dff23c59c8  12/17/29    8/2/94       M
# 150  2e1644ee-f7ca-4700-9b8a-ceb5bfb3efd2    9/2/27  11/30/12       M
#
#          RACE GENDER           BIRTHPLACE  \
# 11   hispanic      F        Seekonk MA US
# 43   hispanic      M         Auburn MA US
# 150  hispanic      M  North Andover MA US
#
#                                               ADDRESS  AGE        BirthPO  \
# 11       77237 Bernadette Turnpike Boston MA 02118 US   64        Seekonk
# 43   129 Ralph Extension Suite 128 Boston MA 02118 US   88         Auburn
# 150          907 Maribel Stravenue Boston MA 02118 US   90  North Andover
#
#     HomeZip HouseholdIncome HouseholdMOE          Family          Married  \
# 11    02118           59589         8491  [80707, 24230]  [175833, 26762]
# ...
